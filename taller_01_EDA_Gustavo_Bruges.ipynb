# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Bruges/CollabAI/blob/main/taller_01_EDA_Gustavo_Bruges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
departamentos = ['Santander', 'Atlántico', 'Norte de Santander']
capitales = ['Bucarmanga', 'Barranquilla', 'Cúcuta']

# %%
print(type(departamentos))
# Out:
# <class 'list'>

# %%
colombia = dict(zip(departamentos,capitales))

# %%
colombia
# Out:
# {'Santander': 'Bucarmanga',
#  'Atlántico': 'Barranquilla',
#  'Norte de Santander': 'Cúcuta',
#  'Valle del Cauca': 'Cali'}

# %%
municipios = ['Floridablanca', 'Girón','Piedecuesta']

# %%
entidades = {'Santander': municipios}

# %%
entidades
# Out:
# {'Santander': ['Floridablanca', 'Girón', 'Piedecuesta']}

# %%
entidades['Santander'][1:2]
# Out:
# ['Girón']

# %%
for dep, cap in colombia.items():
  print(dep,cap)
# Out:
# Santander Bucarmanga
# Atlántico Barranquilla
# Norte de Santander Cúcuta
# Valle del Cauca Cali

# %%
colombia['Valle del Cauca'] = 'Cali'

# %%
wines = pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    int64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 74.7+ KB

# %%
titanic['deck'].value_counts(normalize=True).round(2)*100
# Out:
# deck
# C    29.0
# B    23.0
# D    16.0
# E    16.0
# A     7.0
# F     6.0
# G     2.0
# Name: proportion, dtype: float64

# %%
titanic['sex'].nbytes
# Out:
# 907

# %%
#convertir mi variable object a variable categórica
titanic['sex'] = titanic['sex'].astype('category')

# %%
titanic.groupby('sex')['age'].agg(['mean','max', 'min'])
# Out:
# /tmp/ipykernel_190/2976189990.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby('sex')['age'].agg(['mean','max', 'min'])
#              mean   max   min
# sex
# female  27.915709  63.0  0.75
# male    30.726645  80.0  0.42

# %%
wines['Wine'] = wines['Wine'].astype('category')

# %%
wines.groupby('Wine')['Alcohol'].agg(['mean','median', 'max', 'min']).round(1)
# Out:
# /tmp/ipykernel_190/2769962285.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wines.groupby('Wine')['Alcohol'].agg(['mean','median', 'max', 'min']).round(1)
#       mean  median   max   min
# Wine
# 1     13.7    13.8  14.8  12.8
# 2     12.3    12.3  13.9  11.0
# 3     13.2    13.2  14.3  12.2

# %%
wines.query('Wine==1').head()
# Out:
# /tmp/ipykernel_190/1359342775.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   wines.query('Wine==1').head()
#   Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# ...

# %%
sns.pairplot(titanic)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.set_palette('colorblind')
sns.histplot(data=titanic, x= 'age', hue= 'alone', kde=True, bins = 100)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.groupby(['island','species'])['sex'].value_counts(normalize = True)
# Out:
# island     species    sex
# Biscoe     Adelie     Female    0.500000
#                       Male      0.500000
#            Gentoo     Male      0.512605
#                       Female    0.487395
# Dream      Adelie     Male      0.509091
#                       Female    0.490909
#            Chinstrap  Female    0.500000
#                       Male      0.500000
# Torgersen  Adelie     Female    0.510638
#                       Male      0.489362
# Name: proportion, dtype: float64

# %%
sns.catplot(data=titanic, x = 'sex', kind = 'count', col='survived',hue ='sex')

# %%
# Opción 1: Usar col_wrap con col=
sns.catplot(data=penguins, x='sex', y='flipper_length_mm', hue='species',
            col='island', kind='bar', col_wrap=3)
